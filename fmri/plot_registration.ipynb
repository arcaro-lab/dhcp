# %%
git_dir = 'C:/Users/ArcaroLab/Desktop/git_repos/dhcp'
import os
import sys
#add git_dir to path
sys.path.append(git_dir)
from nilearn import plotting
import numpy as np
import pandas as pd
import dhcp_params as params
from glob import glob as glob
import matplotlib.pyplot as plt
import natsort
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 9
#       7 import numpy as np
#       8 import pandas as pd
# ----> 9 import dhcp_params as params
#      10 from glob import glob as glob
#      11 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'dhcp_params'

# %%
qc_dir = f'{git_dir}/fmri/qc'

#glob images in qc dir
qc_imgs = glob(f'{qc_dir}/reg_plots/*.png')

#natsort images
qc_imgs = natsort.natsorted(qc_imgs)

# %%
#loop through qc iamges and plot them
for im in qc_imgs:
    im = plt.imread(im)
    #plot image no border
    plt.imshow(im)
    plt.axis('off')
    
    plt.pause(0.001)
